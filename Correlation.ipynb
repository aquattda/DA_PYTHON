# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Correlation
# - Visualize the relationship between 2 or more variables

# %% [markdown]
# # 1. Scatter plot

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
def scatter(data, x, y, hue=None, size=None, sizes=None,legend=None, title=None, fontsize=14, figsize=(12,8)):
    plt.figure(figsize= figsize)
    sns.scatterplot(
        data = data, x=x, y=y, size=size, sizes = sizes, legend = legend, hue=hue
    )
    plt.title(title, fontsize=fontsize)

# %%
sns.scatterplot(
    data=tips, x='total_bill', y='tip', hue='sex'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
scatter(data= tips, x='total_bill', y='tip', size='size', hue='sex', sizes=(40,400), legend='full', title='total_bill vs tip'
       )

# %% [markdown]
# # 2. Bubble plot

# %%
midwest = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")
midwest.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percprof  poppovertyknown  percpovertyknown  \
# 0             98       249  ...  4.355859            63628         96.274777
# 1             19        48  ...  2.870315            10529         99.087145
# 2             35        16  ...  4.488572            14235         94.956974
# 3             46       150  ...  4.197800            30337         98.477569
# 4             14         5  ...  3.367680             4815         82.505140
#
# ...

# %%
def buble(data, x,y,circle, cricle_value, title,hue=None):
    # As many colors as there are unique midwest[Çategory']
    categories = np.unique(data[hue])
    colors= [plt.cm.tab10(i/float(len(categories) -1)) for in range(len(categories))]

    #Step2: Draw Scatterplot with unique color for each category
    fig = plt.figure(figsize=(16,10), dpi=80, facecolor='w', edgecolor='k')

    for i, category in enumerate(categories):
        plt.scatter(x,y,data=data.loc[data.category==category, :], s='dot_size', c=np.array(colors[i]))

# %% [markdown]
# # 3.Scatter plot with linear regression line of best fit

# %%
def regplot(data,x,y,color='g',fontsize=14, figsize=(12,8), title=None):
    sns.set_theme(color_codes=True)
    plt.figure(figsize=figsize)
    ax = sns.regplot(x=x,y=y, data=tips, color=color)
    plt.title(title, fontsize=fontsize)

# %%
regplot(x='total_bill', y='tip', title='total_bill', data=tips)

# %% [markdown]
# # 4. Correllogram

# %%
def heatmap(data, figsize=(12,10), title=None, fontsize=14):
    plt.figure(figsize = figsize)
    sns.heatmap(data.corr(), xticklables=data.corr().columns, yticklables=data.corr().columns, cmap='RdYlGn', center=0, annot=True)
    plt.title(title, fontsize=fontsize)

# %%
# df = pd.read_csv("https://github.com/selva86/datasets/master/mtcars.csv") #Link error
# heatmap(tips)

# %%
"""
- Không đọc qua từng ô mà nhìn nhanh qua chart coi có correlation mạnh hay nghịch
- LƯU Ý: Chỉ cần nhìn 1 phần dưới hoặc trên đường chéo chính
- Cần quan tâm đến các màu đặc trưng (Đỏ vs Xanh)
"""

# %% [markdown]
# # 5. Pairwise Plot

# %%
"""
- Hiển thị nhiều biến số theo nhiều biến số voiws nhau
- 
"""

# %% [markdown]
# # Deviation

# %% [markdown]
# # 1. Diverging Bars

# %%
'''
- Gía trị nào xuất hiện nhiều lân nhất hoặc giá trị lớn nhất
- Cơ bản là Bar plot nhưng nó sẽ chia ra 2 giá trị âm và dương
- Trục dọc là các cột (dữ liệu) và số lượng hoặc gì đó để xem sự correlation 
CÓ 2 TRƯỜNG HỢP ĐỂ VẼ:
- Cột có quá nhiều loại khác nhau và tên loại dài nên là để trụ  Y sẽ hợp lý
- Cột có giá trị âm và dương
'''
# Out:
#   Cell In[7], line 1
#     - Gía trị nào xuất hiện nhiều lân nhất hoặc giá trị lớn nhất
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # RANKING

# %%
- So sánh các giá trị để biết được thứ tự....

# %% [markdown]
# # Lollipop Chart

# %%
- Cung là Bar plot nhưng nó đẹp hơn và đỡ thô hơn

# %%
Slope Chart

# %%
- Muốn đo trước và sau của dữ liệu khi thực hiện một chiến dịch gì đó và trước sự kiện và sau sự kiện sẽ có sự thay đổi như thế nào

# %% [markdown]
# # Distribution (Hay bị bỏ qua)

# %%
1. Histogram for Continuous Variable (Popular) => NÊN LÀM Ở ĐẦU

# %%
- Data phân bổ xung quanh vùng dữ liệu nào trong khoảng bao nhiêu
- So sánh giá trị được tốt hơn là dùng giá trị Mean(Việt Nam)
- Không được tự ý chia các khoảng khi chưa có sự chắc chắn
KHI NÀO NÊN DÙNG:
- Khi dữ liệu continuous và lặp lại nhiều
- Check Mean => Có bị bias? (không khách quang)

# %%
2. Density Plot

# %%
- Y chang histogram nhưng nó chia thành các group khác nhaiu
SỰ KHÁC NHAU
- Không hiển thị số lần xuất hiện
- Chỉ hiển thị (số lần xuất hiện \ tổng data)
vd: Độ tuổi KH (50-60) xuất hiện 50 lần nhưng tổng khách hàng là 100 => 0.5 (50%)

# %%
3. Density Curves with Histogram

# %%
- Sự kết hợp giữa Bar chart và histogram
- Có thêm các line để hiển thị mức độ tập trung của dữ liệu

# %%
4. Box plot (Popular Second)

# %%
- Hiển thị quantity theo chart và đặc biệt là nhìn được OUTLIER

# %% [markdown]
# # Population Pyramid

# %%
- Dùng cho Data type Funal
Vd: APP shopee
- Giả sử khi đi mua hàng ở sàn Shopee thì sẽ có nhiều steps khác nhau để mua được 1 món hàng
=> Cần phải kiểm tra xem rằng ở các step nào thì customer sẽ có xu hướng quyết định không mua hàng hoặc là các step bị dư thừa hay ảnh hưởng đến sản phẩm

# %%
Categorical Plots (chủ yếu là bar plot nhưng neesy nhiều thì nó thành catplot)

# %%
Composition

# %%
1. Pie chart

# %%
2. Treemap

# %%
3. Line plot (Thường được vẽ theo ngày tháng hoặc các năm)

# %%
TỔNG KẾT

# %%
- KHI DATA Ở DẠNG SỐ LIỆU VÀ CÓ RẤT NHIỀU GIÁ TRỊ VÀ KHÔNG PHẢI MÌNH CHIA KHOẢNG
+ DÙNG HISTOGRAM
+ BUBBLE PLOT (Dựa vào 25/50/75) để xác định data nằm trong khoảng nào và xác định các giá trị OUTLIER và thông số của nó
- TẠI SAO NÊN DÙNG:
+ Giả sử khi tính giá trị Mean như bình thường thì khi vẽ chart rất có thể sẽ bị bias(dữ liệu không khách quang) 
+ Khi có quá nhiều giá trị mà không thể vẽ cùng một lúc trong trục ngang được
+ Tự ý chia khoảng khi không có sự chắc chắn
# Out:
#   Cell In[2], line 1
#     - KHI DATA Ở DẠNG SỐ LIỆU VÀ CÓ RẤT NHIỀU GIÁ TRỊ VÀ KHÔNG PHẢI MÌNH CHIA KHOẢNG
#           ^
# SyntaxError: invalid syntax
