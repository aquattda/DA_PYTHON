# %%
import pandas as pd
import numpy as np

# %%
sale = pd.read_csv('K/1.csv')
sale.head()
# Out:
#          date  steps  distance_km  calories_burned  active_minutes  \
# 0   8/10/2022   4147         3.11           124.41              41
# 1   11/6/2022    323         0.24             9.69               3
# 2  28/01/2022   6622         4.97           198.66              66
# 3  23/03/2022  11136         8.35           334.08             111
# 4  20/05/2022   2718         2.04            81.54              27
#
#    sleep_hours  water_intake_liters      mood
# 0         10.5                 3.77  stressed
# 1          6.0                 1.90       sad
# 2          6.0                 4.48       sad
# 3          8.0                 1.08     tired
# 4          4.9                 1.00     tired

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 500 non-null    object
#  1   steps                500 non-null    int64
#  2   distance_km          500 non-null    float64
#  3   calories_burned      500 non-null    float64
#  4   active_minutes       500 non-null    int64
#  5   sleep_hours          500 non-null    float64
#  6   water_intake_liters  500 non-null    float64
#  7   mood                 500 non-null    object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 31.4+ KB

# %%
'''
- Date : Time64
'''
sale['date'] = pd.to_datetime(sale['date'], format= "%d/%m/%Y")

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 500 non-null    datetime64[ns]
#  1   steps                500 non-null    int64
#  2   distance_km          500 non-null    float64
#  3   calories_burned      500 non-null    float64
#  4   active_minutes       500 non-null    int64
#  5   sleep_hours          500 non-null    float64
#  6   water_intake_liters  500 non-null    float64
#  7   mood                 500 non-null    object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 31.4+ KB

# %%
from IPython.display import Image
Image("Practice/Skewness_Kurtosis.png")

# %%
'''
- Skewness: Compare chart deviations
=> Skew (+) => Left deviations (dựa vào đuôi) and vice versa
- Kurtosis: Độ nhọn of deviations
=> Càng nhọn thì data chỉ focus vào 1 điểm
'''

# %%
Image("Practice/Use_log.png")

# %%
Image("Practice/missing.png")

# %%
'''
- If Percent > 0.9 => Filling missing values
'''

# %%
Image("Practice/Filling.png")
